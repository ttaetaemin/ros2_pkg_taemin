# %%
from nav2_simple_commander.tobot_navigator import BasicNavigator
import rclpy

rclpy.init()
nav = BasicNavigator()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from nav2_simple_commander.tobot_navigator import BasicNavigator
#       2 import rclpy
#       4 rclpy.init()
#
# ModuleNotFoundError: No module named 'nav2_simple_commander'

# %%
nav.waitUntilNav2Active()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 nav.waitUntilNav2Active()
#
# NameError: name 'nav' is not defined
